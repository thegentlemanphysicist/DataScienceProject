# %% [markdown]
# # Occupation Data based on sex and NOC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#Labour force characteristics by occupation, annual
gov_site_3="https://www150.statcan.gc.ca/n1/tbl/csv/14100335-eng.zip"

# %%
import zipfile, io
import requests
import warnings
warnings.filterwarnings("ignore")

import os.path

if not os.path.isfile('./rawcsv_occupation_Sex/14100335.csv'):
    r = requests.get(gov_site_3, verify=False, )
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall("./rawcsv_occupation_Sex")

# %%
employment_data_occupation_sex = pd.read_csv('./rawcsv_occupation_Sex/14100335.csv', sep=',')
employment_data_occupation_sex
# Out:
#         REF_DATE               GEO           DGUID  \
# 0           1987            Canada  2016A000011124
# 1           1987            Canada  2016A000011124
# 2           1987            Canada  2016A000011124
# 3           1987            Canada  2016A000011124
# 4           1987            Canada  2016A000011124
# ...          ...               ...             ...
# 403915      2020  British Columbia     2016A000259
# 403916      2020  British Columbia     2016A000259
# 403917      2020  British Columbia     2016A000259
# 403918      2020  British Columbia     2016A000259
# 403919      2020  British Columbia     2016A000259
#
#        Labour force characteristics  \
# 0                      Labour force
# 1                      Labour force
# 2                      Labour force
# 3                      Labour force
# 4                      Labour force
# ...                             ...
# 403915     Proportion of employment
# 403916     Proportion of employment
# ...

# %%
employment_data_occupation_sex.head()
# Out:
#    REF_DATE     GEO           DGUID Labour force characteristics  \
# 0      1987  Canada  2016A000011124                 Labour force
# 1      1987  Canada  2016A000011124                 Labour force
# 2      1987  Canada  2016A000011124                 Labour force
# 3      1987  Canada  2016A000011124                 Labour force
# 4      1987  Canada  2016A000011124                 Labour force
#
#   National Occupational Classification (NOC)         Sex      UOM  UOM_ID  \
# 0                     Total, all occupations  Both sexes  Persons     249
# 1                     Total, all occupations       Males  Persons     249
# 2                     Total, all occupations     Females  Persons     249
# 3                 Management occupations [0]  Both sexes  Persons     249
# 4                 Management occupations [0]       Males  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE    VALUE STATUS  SYMBOL  \
# ...

# %%
employment_data_occupation_sex['National Occupational Classification (NOC)'].unique()
# Out:
# array(['Total, all occupations', 'Management occupations [0]',
#        'Senior management occupations [00]',
#        'Specialized middle management occupations [01-05]',
#        'Middle management occupations in retail and wholesale trade and customer services [06]',
#        'Middle management occupations in trades, transportation, production and utilities [07-09]',
#        'Business, finance and administration occupations [1]',
#        'Professional occupations in business and finance [11]',
#        'Administrative and financial supervisors and administrative occupations [12]',
#        'Finance, insurance and related business administrative occupations [13]',
#        'Office support occupations [14]',
#        'Distribution, tracking and scheduling co-ordination occupations [15]',
#        'Natural and applied sciences and related occupations [2]',
#        'Professional occupations in natural and applied sciences [21]',
# ...

# %%
employment_data_occupation_sex['Labour force characteristics'].unique()
# Out:
# array(['Labour force', 'Employment', 'Full-time employment',
#        'Part-time employment', 'Unemployment', 'Unemployment rate',
#        'Proportion of employment'], dtype=object)

# %%
employment_data_occupation_sex['GEO'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia'], dtype=object)

# %%
occupation_sex_simple=employment_data_occupation_sex[['REF_DATE','GEO','Labour force characteristics','National Occupational Classification (NOC)','Sex','VALUE' ]]

# %%
occupation_sex_pivot=occupation_sex_simple.pivot(index=['REF_DATE','GEO','Sex','National Occupational Classification (NOC)'], columns='Labour force characteristics', values='VALUE')
occupation_sex_pivot.head()
# Out:
# Labour force characteristics                                                    Employment  \
# REF_DATE GEO     Sex        National Occupational Classification (NOC)
# 1987     Alberta Both sexes Administrative and financial supervisors and ad...        72.8
#                             Assemblers in manufacturing [95]                           6.8
#                             Assisting occupations in support of health serv...         9.7
#                             Business, finance and administration occupation...       219.5
#                             Care providers and educational, legal and publi...        21.3
#
# Labour force characteristics                                                    Full-time employment  \
# REF_DATE GEO     Sex        National Occupational Classification (NOC)
# 1987     Alberta Both sexes Administrative and financial supervisors and ad...                  63.7
# ...

# %%
occupation_sex_pivot_Canada=occupation_sex_pivot.loc[(slice(None),'Canada','Females'),('Employment','Unemployment rate')]
#occupation_sex_pivot_Canada=occupation_sex_pivot.loc[(slice(None),'Females'),'Unemployment rate']
#occupation_sex_pivot_Canada_df=occupation_sex_pivot_Canada.to_frame()
#occupation_sex_pivot_Canada_df.reset_index(level=['REF_DATE', 'GEO','Sex','National Occupational Classification (NOC)'],inplace=True)
occupation_sex_pivot_Canada.reset_index(level=['REF_DATE', 'GEO','Sex','National Occupational Classification (NOC)'],inplace=True)

occupation_sex_pivot_Canada_df_sorted=occupation_sex_pivot_Canada.sort_values(['REF_DATE','GEO','National Occupational Classification (NOC)'],ascending=(True,True,True))

occupation_sex_pivot_Canada_df_sorted
# Out:
# Labour force characteristics  REF_DATE     GEO      Sex  \
# 0                                 1987  Canada  Females
# 1                                 1987  Canada  Females
# 2                                 1987  Canada  Females
# 3                                 1987  Canada  Females
# 4                                 1987  Canada  Females
# ...                                ...     ...      ...
# 1763                              2020  Canada  Females
# 1764                              2020  Canada  Females
# 1765                              2020  Canada  Females
# 1766                              2020  Canada  Females
# 1767                              2020  Canada  Females
#
# Labour force characteristics         National Occupational Classification (NOC)  \
# 0                             Administrative and financial supervisors and a...
# 1                                              Assemblers in manufacturing [95]
# ...

# %%
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
missing_values=occupation_sex_pivot_Canada_df_sorted[occupation_sex_pivot_Canada_df_sorted['Unemployment rate'].isnull()]
missing_values
# Out:
# Labour force characteristics  REF_DATE     GEO      Sex  \
# 2                                 1987  Canada  Females
# 11                                1987  Canada  Females
# 14                                1987  Canada  Females
# 19                                1987  Canada  Females
# 25                                1987  Canada  Females
# 29                                1987  Canada  Females
# 32                                1987  Canada  Females
# 37                                1987  Canada  Females
# 42                                1987  Canada  Females
# 44                                1987  Canada  Females
# 50                                1987  Canada  Females
# 54                                1988  Canada  Females
# 58                                1988  Canada  Females
# 63                                1988  Canada  Females
# 66                                1988  Canada  Females
# 71                                1988  Canada  Females
# ...

# %%
occupation_sex_pivot_Canada_df_sorted_doprna= occupation_sex_pivot_Canada_df_sorted.dropna(how='all',inplace=True)

# %%
print(occupation_sex_pivot_Canada_df_sorted_doprna)
# Out:
# None

# %%
occupation_sex_pivot_Canada_df_sorted.dropna(inplace=True)

# %%
occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].unique()
# Out:
# array(['Administrative and financial supervisors and administrative occupations [12]',
#        'Assemblers in manufacturing [95]',
#        'Business, finance and administration occupations [1]',
#        'Care providers and educational, legal and public protection support occupations [44]',
#        'Distribution, tracking and scheduling co-ordination occupations [15]',
#        'Finance, insurance and related business administrative occupations [13]',
#        'Harvesting, landscaping and natural resources labourers [86]',
#        'Health occupations [3]',
#        'Industrial, electrical and construction trades [72]',
#        'Labourers in processing, manufacturing and utilities [96]',
#        'Management occupations [0]',
#        'Middle management occupations in retail and wholesale trade and customer services [06]',
#        'Natural and applied sciences and related occupations [2]',
#        'Natural resources, agriculture and related production occupations [8]',
# ...

# %%
conditions= [(occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Administrative and financial supervisors and administrative occupations [12]',
                                                                                                        'Management occupations [0]','Office support occupations [14]',
                                                                                                         'Finance, insurance and related business administrative occupations [13]',
                                                                                                        'Middle management occupations in retail and wholesale trade and customer services [06]',
                                                                                                       'Office support occupations [14]','Service supervisors and specialized service occupations [63]','Business, finance and administration occupations [1]',
                                                                                                        'Specialized middle management occupations [01-05]','Professional occupations in business and finance [11]'])),
              (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Assemblers in manufacturing [95]','Industrial, electrical and construction trades [72]',
                                                                                                       'Labourers in processing, manufacturing and utilities [96]', 'Occupations in manufacturing and utilities [9]',
                                                                                                       'Other installers, repairers and servicers and material handlers [74]','Processing and manufacturing machine operators and related production workers [94]',
                                                                                                       'Trades helpers, construction labourers and related occupations [76]','Distribution, tracking and scheduling co-ordination occupations [15]',
                                                              'Transport and heavy equipment operation and related maintenance occupations [75]' , 'Maintenance and equipment operation trades [73]',
                                                                                                         'Middle management occupations in trades, transportation, production and utilities [07-09]',
                                                                                                        'Processing, manufacturing and utilities supervisors and central control operators [92]'])),
             (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Health occupations [3]','Assisting occupations in support of health services [34]','Technical occupations related to natural and applied sciences [22]','Technical occupations in health [32]',
                                                                                                       'Natural and applied sciences and related occupations [2]','Professional occupations in natural and applied sciences [21]'])),
            (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Care providers and educational, legal and public protection support occupations [44]','Paraprofessional occupations in legal, social, community and education services [42]',
                                                                                                       'Professional occupations in education services [40]','Professional occupations in law and social, community and government services [41]',
                                                                                                      'Retail sales supervisors and specialized sales occupations [62]','Sales and service occupations [6]','Service representatives and other customer and personal services occupations [65]',
                                                                                                      'Service support and other service occupations, n.e.c. [67]','Occupations in education, law and social, community and government services [4]','Sales support occupations [66]','Retail sales supervisors and specialized sales occupations [62]',
                                                                                                       'Trades, transport and equipment operators and related occupations [7]','Sales representatives and salespersons - wholesale and retail trade [64]'])),
            (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Total, all occupations'])),
            (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Harvesting, landscaping and natural resources labourers [86]','Natural resources, agriculture and related production occupations [8]',
                                                                                                      'Workers in natural resources, agriculture and related production [84]','Supervisors and technical occupations in natural resources, agriculture and related production [82]'])),
            (occupation_sex_pivot_Canada_df_sorted['National Occupational Classification (NOC)'].isin(['Occupations in art, culture, recreation and sport [5]','Professional occupations in art and culture [51]',
                                                                                                      'Technical occupations in art, culture, recreation and sport [52]']))]
values=['Admin and Management','Industrials','Health & Science','Service Sector','All Occupation','Agri & Allied','Art & Culture']

# %%
occupation_sex_pivot_Canada_df_sorted['Sector'] = np.select(conditions,values)

# %%
occupation_sex_pivot_Canada_df_sorted
# Out:
# Labour force characteristics  REF_DATE     GEO      Sex  \
# 0                                 1987  Canada  Females
# 1                                 1987  Canada  Females
# 3                                 1987  Canada  Females
# 4                                 1987  Canada  Females
# 5                                 1987  Canada  Females
# 6                                 1987  Canada  Females
# 7                                 1987  Canada  Females
# 8                                 1987  Canada  Females
# 9                                 1987  Canada  Females
# 10                                1987  Canada  Females
# 12                                1987  Canada  Females
# 13                                1987  Canada  Females
# 15                                1987  Canada  Females
# 16                                1987  Canada  Females
# 17                                1987  Canada  Females
# 18                                1987  Canada  Females
# ...

# %%
#plot1=occupation_sex_pivot_Canada_df_sorted[occupation_sex_pivot_Canada_df_sorted.groupby('Sector').mean()]
from numpy import average
df1=occupation_sex_pivot_Canada_df_sorted[occupation_sex_pivot_Canada_df_sorted['Sector'] != 'All Occupation']
#value=round(average( df1['Unemployment rate'], weights = df1['Employment']),2)
#data = {'year':df1['REF_DATE'],'value':round(average( df1['Unemployment rate'], weights = df1['Employment']),2),'Sector':df1['Sector']}
#df_plot=pd.DataFrame.from_dict(data)
#df2= occupation_sex_pivot_Canada_df_sorted[occupation_sex_pivot_Canada_df_sorted.groupby(['REF_DATE','Sector'],as_index=False).mean()]
fig = plt.figure(figsize=(20,10))
#g= sns.lineplot(x="REF_DATE", y="Unemployment rate", hue="Sector", data=df1,ci=None)
g= sns.lineplot(x="REF_DATE", y="Unemployment rate", hue="Sector", data=df1,ci=None)
#sns.lineplot(x="year", y="value", hue="Sector", data=df_plot,ci=None)
#g.set_xticks(x)
#g.set_xticklabels(x_name)
#g.set_axis_labels('Year', 'Unemployment rate')

# %% [markdown]
# # Time series analysis on Female Unemployment data

# %%
#Convert REF_Date to datetime

import datetime

df2= occupation_sex_pivot_Canada_df_sorted.copy(deep=True)

# %%
#Filtering to ALl occupation unemployment data

df2_all=df2[df2['Sector']=="All Occupation"]
#df3= df2_all.groupby('REF_DATE').mean()
#df3.reset_index(level=['REF_DATE'],inplace=True)
df2_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 46 to 1762
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   REF_DATE                                    34 non-null     int64
#  1   GEO                                         34 non-null     object
#  2   Sex                                         34 non-null     object
#  3   National Occupational Classification (NOC)  34 non-null     object
#  4   Employment                                  34 non-null     float64
#  5   Unemployment rate                           34 non-null     float64
#  6   Sector                                      34 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.1+ KB

# %%
df2_all['Date']=pd.to_datetime(df2_all.REF_DATE, format='%Y')

# %%
df2_all.head()
# Out:
# Labour force characteristics  REF_DATE     GEO      Sex  \
# 46                                1987  Canada  Females
# 98                                1988  Canada  Females
# 150                               1989  Canada  Females
# 202                               1990  Canada  Females
# 254                               1991  Canada  Females
#
# Labour force characteristics National Occupational Classification (NOC)  \
# 46                                               Total, all occupations
# 98                                               Total, all occupations
# 150                                              Total, all occupations
# 202                                              Total, all occupations
# 254                                              Total, all occupations
#
# Labour force characteristics  Employment  Unemployment rate          Sector  \
# 46                                5307.7                9.2  All Occupation
# ...

# %%
#Setting datetime column as Index
df2_all=df2_all.set_index('Date')

# %%
#Dropping unnecessray columns
df2_all=df2_all.drop('REF_DATE',axis=1)

# %%
# Plotting autocorrelation

df2_all_shift=df2_all.shift(1)
# %matplotlib inline
plt.rc('figure', figsize=(12, 6))
plt.figure()
pd.plotting.autocorrelation_plot(df2_all_shift["Unemployment rate"].dropna())
plt.title('Autocorrelation for Female unemployment rate - All Occupation')
plt.xlabel('Lag(years)')
# Out:
# Text(0.5, 0, 'Lag(years)')
